# %%
import torch
# from torchsummary import summary
from utils.utils import get_model
from torchinfo import summary


num_classes = 8
model_name = "cnvx_msfpn"

# 모델 가져오기
model, layer_name = get_model(model_name, num_classes)

# 모델 디바이스 지정 (CPU 또는 CUDA)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# 입력 사이즈 지정: (채널, 높이, 너비)
input_size = (3, 224, 224)  # 예: RGB 이미지 224x224

summary(model, input_size=(1, 3, 224, 224), device=device)
# Out:
# ...
# Layer (type:depth-idx)                             Output Shape              Param #
# ...
# ConvNeXt_FPN                                       [1, 8]                    3,146,800
# ├─FeatureListNet: 1-1                              [1, 128, 56, 56]          --
# │    └─Conv2d: 2-1                                 [1, 128, 56, 56]          6,272
# │    └─LayerNorm2d: 2-2                            [1, 128, 56, 56]          256
# │    └─ConvNeXtStage: 2-3                          [1, 128, 56, 56]          --
# │    │    └─Identity: 3-1                          [1, 128, 56, 56]          --
# │    │    └─Sequential: 3-2                        [1, 128, 56, 56]          415,488
# │    └─ConvNeXtStage: 2-4                          [1, 256, 28, 28]          --
# │    │    └─Sequential: 3-3                        [1, 256, 28, 28]          131,584
# │    │    └─Sequential: 3-4                        [1, 256, 28, 28]          1,617,408
# ...
